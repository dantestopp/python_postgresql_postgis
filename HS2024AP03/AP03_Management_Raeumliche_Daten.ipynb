# %% [markdown]
# # Arbeitspaket (AP) 3: Management & Nutzung Räumliche Daten

# %% [markdown]
# ### Angaben Studierende(r) (fehlende Angaben ergänzen)

# %% [markdown]
# <table>
#   <tr>
#     <td>Vorname:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Nachname:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Immatrikulationsnummer:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Modul:</td>
#     <td>Data Science</td>
#   </tr>
#   <tr>
#     <td>Prüfungsdatum / Raum / Zeit:</td>
#     <td>07.10.2024 / Raum: SF O3.54 / 8:00 – 11:45</td>
#   </tr>
#   <tr>
#     <td>Erlaubte Hilfsmittel:</td>
#     <td>w.MA.XX.DS.24HS (Data Science)<br>Open Book, Eigener Computer, Internet-Zugang</td>
#   </tr>
#   <tr>
#   <td>Nicht erlaubt:</td>
#   <td>Nicht erlaubt ist der Einsatz beliebiger Formen von generativer KI (z.B. Copilot, ChatGPT) <br> sowie beliebige Formen von Kommunikation oder Kollaboration mit anderen Menschen.</td>
# </tr>
# </table>

# %% [markdown]
# ## Bewertungskriterien
#
# ### <b style="color: gray;">(max. erreichbare Punkte: 48)</b>
#
# <table>
#   <thead>
#     <tr>
#       <th>Kategorie</th>
#       <th>Beschreibung</th>
#       <th>Punkteverteilung</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Code nicht lauffähig oder Ergebnisse nicht sinnvoll</td>
#       <td>Der Code enthält Fehler, die verhindern, dass er ausgeführt werden kann (z.B. Syntaxfehler) oder es werden Ergebnisse ausgegeben, welche nicht zur Fragestellung passen.</td>
#       <td>0 Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit gravierenden Mängeln</td>
#       <td>Der Code läuft, aber die Ergebnisse sind aufgrund wesentlicher Fehler unvollständig (z.B. fehlende Joins, gravierende Fehler in SQL-Abfragen). Nur geringer Fortschritt erkennbar.</td>
#       <td>25% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit mittleren Mängeln</td>
#       <td>Der Code läuft und liefert teilweise korrekte Ergebnisse, aber es gibt grössere Fehler (z.B. fehlende Spalten, unvollständige SQL-Abfragen). Die Ergebnisse sind nachvollziehbar, aber unvollständig oder ungenau.</td>
#       <td>50% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig, aber mit minimalen Mängeln</td>
#       <td>Der Code läuft und liefert ein weitgehend korrektes Ergebnis, aber kleinere Fehler (z.B. falsche oder fehlende Sortierung, Rundung von Werten falsch) beeinträchtigen die Vollständigkeit des Ergebnisses.</td>
#       <td>75% der max. erreichbaren Punkte</td>
#     </tr>
#     <tr>
#       <td>Code lauffähig und korrekt</td>
#       <td>Der Code läuft einwandfrei und liefert das korrekte Ergebnis ohne Mängel.</td>
#       <td>100% der max. erreichbaren Punkte</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### <b>Python Libraries und Settings</b>

# %%
# Libraries
import os
import folium
import pandas as pd
import geopandas as gpd
from sqlalchemy import create_engine, text

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/python_postgresql_postgis/HS2024AP03

# %% [markdown]
# ## <b>Vorbereitung (Hinweis: dieser Teil wird <u>nicht</u> bewertet)</b>

# %% [markdown]
# #### <b>1.) Starten Sie eine GitHub Codespaces Instanz auf Basis Ihres Forks des folgenden GitHub Repositories:</b>
#
# ##### GitHub-Repository: https://github.com/mario-gellrich-zhaw/python_postgresql_postgis
#
# ##### <span style="color: red;"><b>WICHTIG!!! Verwenden Sie eine GitHub Codespaces Instanz mit ausreichend Arbeitsspeicher (4core, 16GB RAM).</b></span>
#
# <b>Hinweis:</b>
# - Im Unterricht wurden bereits sämtliche Installationen und Einstellungen inkl. der Registrierung des Datenbank Servers auf pgAdmin vorgenommen.
# - Falls Sie die Codespaces-Instanz neu erstellen müssen, folgen Sie bitte den detaillierten Erklärungen auf der README-Seite des GitHub Repositories.

# %% [markdown]
# #### <b>2.) Erstellen und Testen Sie die Datenbankverbindung mit der 'osm_switzerland' Datenbank.</b>

# %%
# Set up Database Connection
user = "pgadmin"
password = "geheim"
host = "localhost"
port = "5432"
database = "osm_switzerland"

# Erstellen der Connection URL
db_connection_url = "postgresql://" + user + ":" + password +\
                    "@" + host + ":" + port + "/" + database

# Erstellen SQLAlchemy Engine
engine = create_engine(db_connection_url)

# Test der Connection
with engine.connect() as connection:
    result = connection.execute(text('SELECT current_database()'))
    print(result.fetchone())

# Verbindung trennen
engine.dispose()
# Out:
# ('osm_switzerland',)

# %% [markdown]
# ## <b>Aufgaben (Dieser Teil wird bewertet!)</b>
# <b>Hinweise zu den folgenden Aufgabenstellungen:</b>
# <ul>
#   <li>In diesem Jupyter Notebook gibt es jeweils zwei Code-Zellen pro Aufgabe:</li>
#   <ol>
#     <li>Eine Codezelle mit Python-Code und einem SQL-Statement für die Datenbank-Abfrage.</li>
#     <li>Eine Codezelle mit Python-Code für die Kartendarstellung der Ergebnisse der jeweiligen SQL-Abfrage.</li>
#   </ol>
#   <li>In den Codezellen für die Datenbank-Abfrage muss jeweils das SQL-Statement ergänzt werden.</li>
#   <li>In den Codezellen für die Kartendarstellung muss nur dann der Python Code ergänzt werden, wenn in der Aufgabe danach gefragt wird.</li>
# </ul>
# <b style="color:red;">Beachten Sie, dass für die Punktevergabe auch die weiteren Anforderungen zu den Fragen unter 'Details zur Aufgabenstellung' herangezogen werden.</b>

# %% [markdown]
# #### <b>Aufgabe (1): Erstellen Sie eine Abfrage sämtlicher Autoreparatur-Werkstätten.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in der Tabelle 'planet_osm_point'.
# - Stellen sie in der Ergebnistabelle die Spalten: osm_id, shop sowie die transformierte Geometrie als Spalte geom dar.
# - Tipp: Die Geometry wird mit Hilfe der Funktion st_transform() transformiert, z.B.: *st_transform(p.way, 4326) AS geom*.
# - Tipp: Autoreparatur-Werkstätten sind mit dem key:value Paar shop='car_repair' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
                p.osm_id,
                p.shop,
                st_transform(p.way, 4326) AS geom
        FROM
                public.planet_osm_point AS p
        WHERE
                p.shop = 'car_repair'
      ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#           osm_id        shop                      geom
# 0     7390840334  car_repair  POINT (8.84295 47.25249)
# 1      339573027  car_repair  POINT (8.83413 47.27604)
# 2      339573017  car_repair  POINT (8.83511 47.27619)
# 3      339573018  car_repair  POINT (8.83448 47.27663)
# 4    11240059282  car_repair  POINT (8.84498 47.30095)
# ..           ...         ...                       ...
# 297  12247129014  car_repair  POINT (8.68212 47.56514)
# 298  11238489214  car_repair  POINT (8.79444 47.53833)
# 299  12855181247  car_repair  POINT (8.81851 47.54032)
# 300  12850641833  car_repair  POINT (8.81921 47.54009)
# 301  12855181248  car_repair  POINT (8.81853 47.54027)
#
# [302 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e999839d9af1397b9116196de75c82e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e999839d9af1397b9116196de75c82e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e999839d9af1397b9116196de75c82e = L.map(
#                 &quot;map_4e999839d9af1397b9116196de75c82e&quot;,
#                 {
#                     center: [47.3917947358392, 8.618542159602649],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c360f8ebede9d1f6380f5ce47b1b6d93 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c360f8ebede9d1f6380f5ce47b1b6d93.addTo(map_4e999839d9af1397b9116196de75c82e);
#
#
#
#         function geo_json_ed016883ef5463bfa7c2bd1155f01de3_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_ed016883ef5463bfa7c2bd1155f01de3 = L.geoJson(null, {
#                 onEachFeature: geo_json_ed016883ef5463bfa7c2bd1155f01de3_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_ed016883ef5463bfa7c2bd1155f01de3_add (data) {
#             geo_json_ed016883ef5463bfa7c2bd1155f01de3
#                 .addData(data);
#         }
#             geo_json_ed016883ef5463bfa7c2bd1155f01de3_add({&quot;bbox&quot;: [8.375916299999998, 47.19164830012115, 8.9187427, 47.64363020002107], &quot;features&quot;: [{&quot;bbox&quot;: [8.8429547, 47.25249140010813, 8.8429547, 47.25249140010813], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8429547, 47.25249140010813], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 7390840334, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8341296, 47.276036600103026, 8.8341296, 47.276036600103026], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8341296, 47.276036600103026], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 339573027, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8351127, 47.27619100010299, 8.8351127, 47.27619100010299], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8351127, 47.27619100010299], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 339573017, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.834484, 47.276632000102914, 8.834484, 47.276632000102914], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.834484, 47.276632000102914], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 339573018, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8449751, 47.300952600097645, 8.8449751, 47.300952600097645], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8449751, 47.300952600097645], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 11240059282, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8395537, 47.29939390009797, 8.8395537, 47.29939390009797], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8395537, 47.29939390009797], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 10720179451, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.9187427, 47.3295990000914, 8.9187427, 47.3295990000914], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.9187427, 47.3295990000914], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 1157271363, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8458396, 47.439674300067125, 8.8458396, 47.439674300067125], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.8458396, 47.439674300067125], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;7&quot;, &quot;properties&quot;: {&quot;osm_id&quot;: 3097655049, &quot;shop&quot;: &quot;car_repair&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8694183, 47.49690240005435, 8.8694183, 47.49690240005435], &quot;geometry&qu

# %% [markdown]
# #### <b>Aufgabe (2) Erstellen Sie eine Abfrage aller Biergärten.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in den Tabellen 'planet_osm_point'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, amenity, name und die transformierte Geometrie als Spalte geom dar.
# - Tipp: Biergärten sind mit dem key:value Paar amenity='biergarten' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
                p.osm_id,
                p.amenity,
				p.name,
                st_transform(p.way, 4326) AS geom
        FROM
                public.planet_osm_point AS p
        WHERE
                p.amenity='biergarten'
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf.head()
# Out:
#        osm_id     amenity            name                      geom
# 0   768907979  biergarten    Engel Lounge  POINT (8.67547 47.23005)
# 1  2518707388  biergarten  zum Adlerhorst  POINT (8.68977 47.38973)
# 2  2679062372  biergarten  Gamschtä Träff  POINT (8.76787 47.23535)

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=8, 
               tiles='CartoDB positron')

# Map settings
folium.GeoJson(
    gdf,
    name='map'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16c820f89b4f9dc35031d94079633994 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16c820f89b4f9dc35031d94079633994&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16c820f89b4f9dc35031d94079633994 = L.map(
#                 &quot;map_16c820f89b4f9dc35031d94079633994&quot;,
#                 {
#                     center: [47.28504446676764, 8.711035866666665],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90270485ae03c5e965e5721e2764c82e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_90270485ae03c5e965e5721e2764c82e.addTo(map_16c820f89b4f9dc35031d94079633994);
#
#
#
#         function geo_json_c26e0bf963b243bfad4009f5c631c059_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_c26e0bf963b243bfad4009f5c631c059 = L.geoJson(null, {
#                 onEachFeature: geo_json_c26e0bf963b243bfad4009f5c631c059_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_c26e0bf963b243bfad4009f5c631c059_add (data) {
#             geo_json_c26e0bf963b243bfad4009f5c631c059
#                 .addData(data);
#         }
#             geo_json_c26e0bf963b243bfad4009f5c631c059_add({&quot;bbox&quot;: [8.6754669, 47.23005180011294, 8.767871899999998, 47.38973230007818], &quot;features&quot;: [{&quot;bbox&quot;: [8.6754669, 47.23005180011294, 8.6754669, 47.23005180011294], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.6754669, 47.23005180011294], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;Engel Lounge&quot;, &quot;osm_id&quot;: 768907979}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.6897688, 47.38973230007818, 8.6897688, 47.38973230007818], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.6897688, 47.38973230007818], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;zum Adlerhorst&quot;, &quot;osm_id&quot;: 2518707388}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.767871899999998, 47.235349300111814, 8.767871899999998, 47.235349300111814], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.767871899999998, 47.235349300111814], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;amenity&quot;: &quot;biergarten&quot;, &quot;name&quot;: &quot;Gamscht\u00e4 Tr\u00e4ff&quot;, &quot;osm_id&quot;: 2679062372}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_c26e0bf963b243bfad4009f5c631c059.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_c26e0bf963b243bfad4009f5c631c059.addTo(map_16c820f89b4f9dc35031d94079633994);
#
#
#             var layer_control_5257babdfd928d5087fdbab32ed44d61_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_90270485ae03c5e965e5721e2764c82e,
#                 },
#                 overlays :  {
#                     &quot;map&quot; : geo_json_c26e0bf963b243bfad4009f5c631c059,
#                 },
#             };
#             let layer_control_5257babdfd928d5087fdbab32ed44d61 = L.control.layers(
#                 layer_control_5257babdfd928d5087fdbab32ed44d61_layers.base_layers,
#                 layer_control_5257babdfd928d5087fdbab32ed44d61_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_16c820f89b4f9dc35031d94079633994);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### <b>Aufgabe (3): Erstellen Sie eine Abfrage aller Gebäude in der Stadthausstrasse in Winterthur, welche vollständige Adressangaben besitzen.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in der Tabelle 'planet_osm_polygon'.
# - Vollständige Adressangabe bedeutet: Strassenname, Haunummer, PLZ, Gemeindename sind vorhanden.
# - Stellen Sie in der Ergebnistabelle sämtliche Adressangaben sowie die transformierte Geometrie als Spalte geom dar.
# - Verwenden Sie für die Darstellung als Hintergrundkarte ein Satellitenbild (ESRIWorldImagery) als maptile.
# - Tipp: Gebäude sind in der Spalte 'building' klassifiziert. Mit *WHERE building IS NOT NULL* können Sie Gebäude filtern.
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT
                p.osm_id,
                p."addr:street",
                p."addr:housenumber",
                p."addr:city",
                p."addr:postcode",
                st_transform(p.way, 4326) AS geom
        FROM
                public.planet_osm_polygon AS p
        WHERE
                p."addr:street" = 'Stadthausstrasse'
                AND p."addr:housenumber" IS NOT NULL
                AND p."addr:city" = 'Winterthur'
                AND p."addr:postcode" IS NOT NULL
				AND p.building IS NOT NULL
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#        osm_id       addr:street addr:housenumber   addr:city addr:postcode  \
# 0    75027485  Stadthausstrasse               31  Winterthur          8400
# 1    75027472  Stadthausstrasse               35  Winterthur          8400
# 2    75027503  Stadthausstrasse               37  Winterthur          8400
# 3    75027432  Stadthausstrasse               39  Winterthur          8400
# 4   230520600  Stadthausstrasse               61  Winterthur          8400
# ..        ...               ...              ...         ...           ...
# 56  232998352  Stadthausstrasse              133  Winterthur          8400
# 57  188158693  Stadthausstrasse              119  Winterthur          8400
# 58  188158697  Stadthausstrasse              117  Winterthur          8400
# 59  188158696  Stadthausstrasse              115  Winterthur          8400
# 60  188158695  Stadthausstrasse              113  Winterthur          8400
#
#                                                  geom
# 0   POLYGON ((8.73162 47.50041, 8.73165 47.50029, ...
# 1   POLYGON ((8.73153 47.5004, 8.73157 47.50026, 8...
# 2   POLYGON ((8.73146 47.5004, 8.73149 47.50028, 8...
# 3   POLYGON ((8.73111 47.50039, 8.73115 47.50025, ...
# 4   POLYGON ((8.72952 47.5002, 8.72955 47.50006, 8...
# ..                                                ...
# 56  POLYGON ((8.72543 47.4995, 8.72546 47.49949, 8...
# 57  POLYGON ((8.72634 47.49979, 8.7264 47.49961, 8...
# 58  POLYGON ((8.72682 47.49986, 8.72687 47.49972, ...
# 59  POLYGON ((8.72694 47.49988, 8.72696 47.49974, ...
# 60  POLYGON ((8.72702 47.4999, 8.72706 47.49975, 8...
#
# [61 rows x 6 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=17, 
               tiles='ESRIWorldImagery')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    fill_color='greenyellow'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7618329abf92abe24c09c583e7dfe203 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7618329abf92abe24c09c583e7dfe203&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7618329abf92abe24c09c583e7dfe203 = L.map(
#                 &quot;map_7618329abf92abe24c09c583e7dfe203&quot;,
#                 {
#                     center: [47.500044957105665, 8.727995077567487],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 17,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6156f04a73a15015363d5b2e7bdc557 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f6156f04a73a15015363d5b2e7bdc557.addTo(map_7618329abf92abe24c09c583e7dfe203);
#
#
#             var choropleth_94727466075f29a09c98722687c3f3f0 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_1ec59da7a8fa1a3e4e58a5382cbd6a66_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;greenyellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_1ec59da7a8fa1a3e4e58a5382cbd6a66_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_1ec59da7a8fa1a3e4e58a5382cbd6a66 = L.geoJson(null, {
#                 onEachFeature: geo_json_1ec59da7a8fa1a3e4e58a5382cbd6a66_onEachFeature,
#
#                 style: geo_json_1ec59da7a8fa1a3e4e58a5382cbd6a66_styler,
#             ...{
# }
#         });
#
#         function geo_json_1ec59da7a8fa1a3e4e58a5382cbd6a66_add (data) {
#             geo_json_1ec59da7a8fa1a3e4e58a5382cbd6a66
#                 .addData(data);
#         }
#             geo_json_1ec59da7a8fa1a3e4e58a5382cbd6a66_add({&quot;bbox&quot;: [8.724050699999998, 47.49938870005378, 8.733014099999998, 47.50121620005338], &quot;features&quot;: [{&quot;bbox&quot;: [8.731624, 47.50028750005359, 8.731978, 47.500420700053546], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.731624, 47.500405200053564], [8.7316525, 47.50028750005359], [8.7316998, 47.5002887000536], [8.731978, 47.500300700053586], [8.731965899999999, 47.500420700053546], [8.731624, 47.500405200053564]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Winterthur&quot;, &quot;addr:housenumber&quot;: &quot;31&quot;, &quot;addr:postcode&quot;: &quot;8400&quot;, &quot;addr:street&quot;: &quot;Stadthausstrasse&quot;, &quot;osm_id&quot;: 75027485}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7315315, 47.50025950005359, 8.7316566, 47.500405200053564], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.7315315, 47.50040130005357], [8.7315686, 47.50025950005359], [8.7316566, 47.50027100005358], [8.7316525, 47.50028750005359], [8.731624, 47.500405200053564], [8.7315315, 47.50040130005357]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Winterthur&quot;, &quot;addr:housenumber&quot;: &quot;35&quot;, &quot;addr:postcode&quot;: &quot;8400&quot;, &quot;addr:street&quot;: &quot;Stadthausstrasse&quot;, &quot;osm_id&quot;: 75027472}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7314585, 47.5002312000536, 8.7315768, 47.50040130005357], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.7314585, 47.50039990005357], [8.731486299999998, 47.50028070005358], [8.731496799999999, 47.500235200053595], [8.731525399999999, 47.500237200053604], [8.731527, 47.5002312000536], [8.7315768, 47.5002361000536], [8.7315686, 47.50025950005359], [8.7315315, 47.50040130005357], [8.7314585, 47.50039990005357]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Winterthur&quot;, &quot;addr:housenumber&quot;: &quot;37&quot;, &quot;addr:postcode&quot;: &quot;8400&quot;, &quot;addr:street&quot;: &quot;Stadthausstrasse&quot;, &quot;osm_id&quot;: 75027503}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.731112100000002, 47.5002527000536, 8.731486299999998, 47.50039990005357], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.731112100000002, 47.500385800053564], [8.7311473, 47.5002527000536], [8.731275400000001, 47.50026410005359], [8.7312753, 47.50031650005357], [8.731391199999997, 47.500320600053584], [8.7313974, 47.5002757000535

# %% [markdown]
# #### <b>Aufgabe (4): Erstellen Sie eine Abfrage aller Strassen welche als 'motorway' klassifiziert sind.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Informationen in der Tabelle 'planet_osm_roads'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, highway und die transformierte Geometrie als Spalte geom dar.
# - Tipp: Motorways sind mit dem key:value Paar highway='motorway' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 6)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT p.osm_id, highway, st_transform(p.way, 4326) AS geom
FROM public.planet_osm_roads AS p
WHERE p.highway='motorway'
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#          osm_id   highway                                               geom
# 0     546365250  motorway     LINESTRING (8.83096 47.26077, 8.8309 47.26063)
# 1     546365251  motorway    LINESTRING (8.83104 47.26094, 8.83096 47.26077)
# 2      40528299  motorway    LINESTRING (8.83122 47.26097, 8.83134 47.26125)
# 3      40528306  motorway    LINESTRING (8.83116 47.26122, 8.83104 47.26094)
# 4     546365253  motorway  LINESTRING (8.8314 47.2618, 8.83129 47.26153, ...
# ...         ...       ...                                                ...
# 1133   23800819  motorway      LINESTRING (8.5722 47.42817, 8.57232 47.4277)
# 1134   14873984  motorway     LINESTRING (8.57248 47.4276, 8.57238 47.42797)
# 1135   14874047  motorway  LINESTRING (8.57232 47.4277, 8.57244 47.42726,...
# 1136   26579979  motorway  LINESTRING (8.57327 47.42498, 8.57291 47.42615...
# 1137  257163010  motorway  LINESTRING (8.57277 47.42616, 8.57296 47.42553...
#
# [1138 rows x 3 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    line_weight=3,
    line_color='red'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60f6c82d91a25d48a6c6334a8836d4fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60f6c82d91a25d48a6c6334a8836d4fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60f6c82d91a25d48a6c6334a8836d4fb = L.map(
#                 &quot;map_60f6c82d91a25d48a6c6334a8836d4fb&quot;,
#                 {
#                     center: [47.39059021538855, 8.58229609138885],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6f6a854dfcf6c1a9c846885cdfdf281 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d6f6a854dfcf6c1a9c846885cdfdf281.addTo(map_60f6c82d91a25d48a6c6334a8836d4fb);
#
#
#             var choropleth_d3855b3972e6befffdbfae55cc5e0f5f = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_f443e3de2b23630b36c7ee6afbf14593_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_f443e3de2b23630b36c7ee6afbf14593_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_f443e3de2b23630b36c7ee6afbf14593 = L.geoJson(null, {
#                 onEachFeature: geo_json_f443e3de2b23630b36c7ee6afbf14593_onEachFeature,
#
#                 style: geo_json_f443e3de2b23630b36c7ee6afbf14593_styler,
#             ...{
# }
#         });
#
#         function geo_json_f443e3de2b23630b36c7ee6afbf14593_add (data) {
#             geo_json_f443e3de2b23630b36c7ee6afbf14593
#                 .addData(data);
#         }
#             geo_json_f443e3de2b23630b36c7ee6afbf14593_add({&quot;bbox&quot;: [8.3632475, 47.19620480012019, 8.9032688, 47.56752360003842], &quot;features&quot;: [{&quot;bbox&quot;: [8.8308994, 47.26063240010636, 8.830962599999998, 47.260768900106335], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.830962599999998, 47.260768900106335], [8.8308994, 47.26063240010636]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365250}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.830962599999998, 47.260768900106335, 8.8310407, 47.260935100106295], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8310407, 47.260935100106295], [8.830962599999998, 47.260768900106335]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365251}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8312169, 47.260969100106294, 8.831339299999998, 47.26124960010623], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8312169, 47.260969100106294], [8.831339299999998, 47.26124960010623]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 40528299}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8310407, 47.260935100106295, 8.8311646, 47.26121720010624], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8311646, 47.26121720010624], [8.8310407, 47.260935100106295]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 40528306}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8311646, 47.26121720010624, 8.8313998, 47.26180450010611], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8313998, 47.26180450010611], [8.8312908, 47.261525300106165], [8.8311646, 47.26121720010624]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365253}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.8321748, 47.26389860010566, 8.832219099999998, 47.26411770010561], &quot;geometry&quot;: {&quot;coordinates&quot;: [[8.8321748, 47.26389860010566], [8.832219099999998, 47.26411770010561]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;highway&quot;: &quot;motorway&quot;, &quot;osm_id&quot;: 546365255}, &quot;type

# %% [markdown]
# #### <b>Aufgabe (5): Erstellen Sie eine Abfrage aller Flüsse. Generieren Sie zusätzlich Buffer um die Flüsse mit einer Breite von 2000m.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Informationen in der Tabelle 'planet_osm_line'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, waterway sowie die transformierte Geometrie als Spalte geom dar.
# - Tipp: Flüsse sind mit dem key:value Paar waterway='river' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
# - Tipp: Per Default wird für jedes Fluss-Segment ein separater Buffer erstellt. Es ist nicht notwendig daraus einen einzelnen Buffer zu generieren.
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT 
            1 as group_id,
            ST_TRANSFORM(ST_UNION(ST_Buffer(p.way::geometry, 2000)), 4326) AS geom
        FROM public.planet_osm_line AS p
        WHERE
            waterway = 'river'
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#    group_id                                               geom
# 0         1  MULTIPOLYGON (((8.13154 47.58872, 8.12999 47.5...

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=10, 
               tiles='CartoDB positron')

# Map settings
folium.Choropleth(
    geo_data=gdf,
    name='map',
    fill_color='greenyellow'
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c334025f843cc33473b6f597bde0e7ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c334025f843cc33473b6f597bde0e7ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c334025f843cc33473b6f597bde0e7ac = L.map(
#                 &quot;map_c334025f843cc33473b6f597bde0e7ac&quot;,
#                 {
#                     center: [47.43116219007231, 8.638810607760538],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bc1c28b1ffef83a581857dfe05b57da = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1bc1c28b1ffef83a581857dfe05b57da.addTo(map_c334025f843cc33473b6f597bde0e7ac);
#
#
#             var choropleth_7e0d4eb049fee962b0f191b41e316797 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_9510aa86293230c61dc96fc12ea000a1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;greenyellow&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_9510aa86293230c61dc96fc12ea000a1_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_9510aa86293230c61dc96fc12ea000a1 = L.geoJson(null, {
#                 onEachFeature: geo_json_9510aa86293230c61dc96fc12ea000a1_onEachFeature,
#
#                 style: geo_json_9510aa86293230c61dc96fc12ea000a1_styler,
#             ...{
# }
#         });
#
#         function geo_json_9510aa86293230c61dc96fc12ea000a1_add (data) {
#             geo_json_9510aa86293230c61dc96fc12ea000a1
#                 .addData(data);
#         }
#             geo_json_9510aa86293230c61dc96fc12ea000a1_add({&quot;bbox&quot;: [8.128864778071952, 47.15464847188619, 8.978196660233557, 47.7076709834925], &quot;features&quot;: [{&quot;bbox&quot;: [8.128864778071952, 47.15464847188619, 8.978196660233557, 47.7076709834925], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[8.131538626424437, 47.58871548679136], [8.129988975328665, 47.59084857032682], [8.129086127229122, 47.593144466320915], [8.128864778071952, 47.59551492934511], [8.129333434181127, 47.597868859928624], [8.130474085365197, 47.600115806054575], [8.132242897038845, 47.602169437929355], [8.134571894761411, 47.603950862682495], [8.13737157645654, 47.60539165205715], [8.138500476456539, 47.60586225935997], [8.141149376388235, 47.60677158031385], [8.141838476388234, 47.60696153959371], [8.143101518231434, 47.60727304660928], [8.143776318231435, 47.607420414141274], [8.1467050666078, 47.6078816084551], [8.1483305666078, 47.60804237161783], [8.1510970055395, 47.60817016016981], [8.153859661577183, 47.60800942081929], [8.155765461577182, 47.60779766920662], [8.157998669413875, 47.607332235599934], [8.1588565319939, 47.60809265435576], [8.160380566727296, 47.60927607060821], [8.161867566727297, 47.610290005506], [8.163720046686187, 47.61139044815261], [8.16534624668619, 47.612229993776126], [8.168238814762569, 47.61344838534698], [8.16987061476257, 47.613998071459605], [8.17213236761237, 47.614634005018786], [8.172207092404285, 47.61465108471394], [8.173198128462426, 47.616094370467366], [8.173355103563077, 47.61631700400707], [8.174130603563077, 47.61738859518378], [8.174302488348491, 47.61761980576473], [8.177086188348492, 47.62126641929868], [8.179630050638552, 47.623768417086985], [8.180908650638555, 47.624738467844324], [8.18101658104244, 47.62481961349889], [8.18159658104244, 47.625251746343444], [8.182157937687638, 47.625651346191695], [8.184415037687637, 47.62718659586448], [8.186258695302453, 47.62827989247297], [8.188181795302453, 47.62927171000079], [8.189767106683263, 47.63000220103984], [8.190587506683265, 47.63033833449916], [8.193648113049433, 47.63133837235179], [8.197664613049431, 47.63234685340994], [8.200241901173664, 47.632849872021936], [8.202901615231404, 47.633088619873824], [8.206755315231405, 47.63323858518685], [8.211272770766215, 47.63302921172998], [8.215112970766214, 47.63251802791792], [8.218562741000637, 47.63181021558686], [8.221170341000636, 47.631075372654045], [8.22135331459501, 47.6310230054822], [8.221949514595009, 47.63084974234197], [8.223774101607267, 47.63031924488816], [8.22729452125791, 47.6289593437629], [8.22961762125791, 47.62780905851465], [8.232188394848135, 47.626259206403375],

# %% [markdown]
# #### <b>Aufgabe (6): Erstellen Sie eine Abfrage der Bäckerei-Geschäfte in Zürich und Winterthur.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die benötigten Daten in den Tabellen 'planet_osm_point' (Backereien).
# - Verwenden Sie die Städtenamen aus den Adressangaben für die Abfrage der Bäckerei-Standorte (Zürich, Winterthur).
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, shop, name, "addr:city" sowie die transformierte Geometrie als geom dar.
# - Wählen Sie eine Satelliten Karte von ESRI als Hintergrundkarte (maptile).
# - Sortieren Sie die Bäckerei-Geschäfte aufsteigend nach osm_id.
# - Tipp: Bäckerei-Geschäfte sind mit dem key:value Paar shop='bakery' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """
SELECT osm_id, shop, name, "addr:city", st_transform(p.way, 4326) AS geom
FROM planet_osm_point p
WHERE (p."addr:city" = 'Zürich' or p."addr:city" = 'Winterthur') AND p.shop = 'bakery'
ORDER BY osm_id ASC
     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf
# Out:
#           osm_id    shop                  name addr:city  \
# 0      252457457  bakery  Steiner Flughafebeck    Zürich
# 1      266630770  bakery           Brezelkönig    Zürich
# 2      267879346  bakery       Walter Buchmann    Zürich
# 3      268602152  bakery               Moser's    Zürich
# 4      270794699  bakery            John Baker    Zürich
# ..           ...     ...                   ...       ...
# 102  10884168277  bakery              Juliette    Zürich
# 103  10946043353  bakery         Babu's Bakery    Zürich
# 104  10955852823  bakery          Täglich Brot    Zürich
# 105  11951988149  bakery                Wagner    Zürich
# 106  12368630564  bakery                 Tsugi    Zürich
#
#                          geom
# 0    POINT (8.49779 47.40311)
# 1    POINT (8.48875 47.39147)
# 2     POINT (8.5191 47.36258)
# 3     POINT (8.54945 47.3632)
# 4    POINT (8.56645 47.36493)
# ..                        ...
# 102   POINT (8.5328 47.36658)
# 103  POINT (8.51568 47.37473)
# 104  POINT (8.50705 47.36079)
# 105   POINT (8.51763 47.3698)
# 106   POINT (8.53092 47.3933)
#
# [107 rows x 5 columns]

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=12, 
               tiles='ESRIWorldImagery')

# Map settings
folium.GeoJson(
    gdf,
    name='map',
).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c5497d0d181a47a28b8eca78655ee09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c5497d0d181a47a28b8eca78655ee09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c5497d0d181a47a28b8eca78655ee09 = L.map(
#                 &quot;map_6c5497d0d181a47a28b8eca78655ee09&quot;,
#                 {
#                     center: [47.39487878605834, 8.555985045794392],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9639a27941c210864a97de426158f0fb = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9639a27941c210864a97de426158f0fb.addTo(map_6c5497d0d181a47a28b8eca78655ee09);
#
#
#
#         function geo_json_5e51818f661e801c1dd856e3a69e6ece_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_5e51818f661e801c1dd856e3a69e6ece = L.geoJson(null, {
#                 onEachFeature: geo_json_5e51818f661e801c1dd856e3a69e6ece_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_5e51818f661e801c1dd856e3a69e6ece_add (data) {
#             geo_json_5e51818f661e801c1dd856e3a69e6ece
#                 .addData(data);
#         }
#             geo_json_5e51818f661e801c1dd856e3a69e6ece_add({&quot;bbox&quot;: [8.481048199999998, 47.33904520008934, 8.7625839, 47.51028540005134], &quot;features&quot;: [{&quot;bbox&quot;: [8.497792, 47.40310610007525, 8.497792, 47.40310610007525], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.497792, 47.40310610007525], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Steiner Flughafebeck&quot;, &quot;osm_id&quot;: 252457457, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.4887528, 47.3914676000778, 8.4887528, 47.3914676000778], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.4887528, 47.3914676000778], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Brezelk\u00f6nig&quot;, &quot;osm_id&quot;: 266630770, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5191037, 47.36258390008416, 8.5191037, 47.36258390008416], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5191037, 47.36258390008416], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Walter Buchmann&quot;, &quot;osm_id&quot;: 267879346, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5494522, 47.36320120008403, 8.5494522, 47.36320120008403], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5494522, 47.36320120008403], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Moser\u0027s&quot;, &quot;osm_id&quot;: 268602152, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5664519, 47.36492500008365, 8.5664519, 47.36492500008365], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5664519, 47.36492500008365], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;John Baker&quot;, &quot;osm_id&quot;: 270794699, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5540543, 47.369558800082636, 8.5540543, 47.369558800082636], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5540543, 47.369558800082636], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Caf\u00e9 Berner&quot;, &quot;osm_id&quot;: 270799257, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.7313948, 47.49943290005378, 8.7313948, 47.49943290005378], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.7313948, 47.49943290005378], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Winterthur&quot;, &quot;name&quot;: &quot;Grabe-Beck&quot;,

# %% [markdown]
# #### <b>Aufgabe (7): Erstellen Sie eine Abfrage sämtlicher Coiffeur-Geschäfte in einem Radius von 500m um den Hauptbahnhof in Zürich.</b>
# <b>Details zur Aufgabenstellung:</b>
# - Sie finden die Daten in der Tabelle 'planet_osm_point'.
# - Berechnen Sie in der Abfrage die Distanz jedes Coiffeur-Geschäfts zum Hauptbahnhof in Metern als Spalte 'distance_meters'.
# - Stellen Sie in der Ergebnistabelle die Spalten: osm_id, shop, name, distance_meters, sowie die transformierte Geometrie als geom dar.
# - Wählen Sie eine Satelliten Karte von ESRI als Hintergrundkarte (maptile).
# - Integrieren Sie in die Kartendarstellung den Namen (Spalte 'name') der Coiffeur-Geschäfte als Popup.
# - Tipp: Coiffeur-Geschäfte sind mit dem key:value Paar shop='hairdresser' in der OpenStreetMap Map-Feature Übersicht angegeben.
# -  vgl: https://wiki.openstreetmap.org/wiki/Map_features
#
# <b style="color: gray;">(max. erreichbare Punkte: 8)</b>

# %%
# Engine für Datenbankverbindung erstellen
engine = create_engine(db_connection_url)  

# Ergänzen Sie die SQL-Abfrage, um die Aufgabe zu lösen
sql = """SELECT 
  osm_id, shop, name,
  ST_Distance(
    ST_Transform(p.way, 4326)::geography,
  -- Zürich, Grossmünster
    ST_SetSRID(ST_MakePoint(8.5403, 47.3781), 4326)::geography
  ) AS distance_meters,
  ST_Transform(p.way, 4326) AS way_transformed
FROM 
public.planet_osm_point AS p
WHERE 
shop = 'hairdresser'
AND
ST_DWithin(
       ST_Transform(p.way, 4326)::geography,
  -- Zürich, Grossmünster
    ST_SetSRID(ST_MakePoint(8.5403, 47.3781), 4326)::geography,
        500
    )

     ;"""

# Ergebnis in GeoDataFrame abspeichern
gdf = gpd.GeoDataFrame.from_postgis(sql, engine)

# Datenbankverbindung trennen
engine.dispose()

# Zeigen des GeoDataFrames
gdf.head()

# %% [markdown]
# ##### <b>Kartendarstellung Ergebnis (nur anpassen, falls in der Aufgabe danach gefragt wird)</b>

# %%
# Projektion definieren (WGS84)
if gdf.crs is None:
    gdf.set_crs(epsg=4326, inplace=True)
else:
    pass

# Latitude und Longitude für die Zentrierung der Karte ermitteln
centroids = gdf.geometry.centroid
lon = centroids.x.mean()
lat = centroids.y.mean()

# Initialisieren der Map
m = folium.Map(location=[lat, lon], 
               zoom_start=16, 
               tiles='ESRIWorldImagery')

# Map settings
folium.GeoJson(
    gdf,
    name='map',
        popup=folium.GeoJsonPopup(fields=['name'])

).add_to(m)

folium.LayerControl().add_to(m)

# Plot map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60ee03faa2dccebb18edc164f73d49f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60ee03faa2dccebb18edc164f73d49f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60ee03faa2dccebb18edc164f73d49f9 = L.map(
#                 &quot;map_60ee03faa2dccebb18edc164f73d49f9&quot;,
#                 {
#                     center: [47.39487878605834, 8.555985045794392],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22c68dc61a781f6c123c1080a9c77412 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22c68dc61a781f6c123c1080a9c77412.addTo(map_60ee03faa2dccebb18edc164f73d49f9);
#
#
#
#         function geo_json_2f1f4c4f86f824ecc8b35223904147b2_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_2f1f4c4f86f824ecc8b35223904147b2 = L.geoJson(null, {
#                 onEachFeature: geo_json_2f1f4c4f86f824ecc8b35223904147b2_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_2f1f4c4f86f824ecc8b35223904147b2_add (data) {
#             geo_json_2f1f4c4f86f824ecc8b35223904147b2
#                 .addData(data);
#         }
#             geo_json_2f1f4c4f86f824ecc8b35223904147b2_add({&quot;bbox&quot;: [8.481048199999998, 47.33904520008934, 8.7625839, 47.51028540005134], &quot;features&quot;: [{&quot;bbox&quot;: [8.497792, 47.40310610007525, 8.497792, 47.40310610007525], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.497792, 47.40310610007525], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Steiner Flughafebeck&quot;, &quot;osm_id&quot;: 252457457, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.4887528, 47.3914676000778, 8.4887528, 47.3914676000778], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.4887528, 47.3914676000778], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Brezelk\u00f6nig&quot;, &quot;osm_id&quot;: 266630770, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5191037, 47.36258390008416, 8.5191037, 47.36258390008416], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5191037, 47.36258390008416], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Walter Buchmann&quot;, &quot;osm_id&quot;: 267879346, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5494522, 47.36320120008403, 8.5494522, 47.36320120008403], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5494522, 47.36320120008403], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;Moser\u0027s&quot;, &quot;osm_id&quot;: 268602152, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5664519, 47.36492500008365, 8.5664519, 47.36492500008365], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5664519, 47.36492500008365], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;4&quot;, &quot;properties&quot;: {&quot;addr:city&quot;: &quot;Z\u00fcrich&quot;, &quot;name&quot;: &quot;John Baker&quot;, &quot;osm_id&quot;: 270794699, &quot;shop&quot;: &quot;bakery&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [8.5540543, 47.369558800082636, 8.5540543, 47.369558800082636], &quot;geometry&quot;: {&quot;coordinates&quot;: [8.5540543, 47.369558800082636], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;5&quot;, &quot;properties&quot;: {&qu

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('IP Address:', socket.gethostbyname(socket.gethostname()))
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-10-04 09:32:47
# Python Version: 3.12.1
# IP Address: 127.0.0.1
# -----------------------------------
